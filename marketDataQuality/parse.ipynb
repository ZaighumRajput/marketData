# %%
import re
import sys
import glob

# %%
import pandas as pd

# %%
import os

# %%
os.curdir
# Out:
# '.'

# %%
os.chdir("C:\\")

# %%
arange(1455,1473)
# Out:
# array([1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465,
#        1466, 1467, 1468, 1469, 1470, 1471, 1472])

# %%
subsetRiskFactorsIR = pd.read_csv('Risk Factor Shocks_20140829.csv', usecols=[0,'IR_EURPC1', 'IR_EURPC2', 'IR_EURPC3', 'IR_EURPC4', 1260, 1261, 1262, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465,1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473], index_col=0)
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1070: DtypeWarning: Columns (0,1181,1182,1183,1184,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1260,1261,1262) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
subsetRiskFactorsIR.to_csv('C:/toy/RiskFactorsIR_subset_ZR3.csv')

# %%
scenarios = subsetRiskFactorsIR.ix[4:50000].astype(float)

# %%
sortedScenarios = scenarios.sort(scenarios.columns.values.tolist(),ascending=True)

# %%
sortedScenarios
# Out:
#        IR_EURPC1  IR_EURPC2  IR_EURPC3  IR_EURPC4  IRIV_EUR  IRIV_GBP  \
# 9128     -44.898   -7.27860    4.54360    7.49880  2.743735  2.721304
# 28648    -44.898   -1.40520    8.86460    1.64480  2.807189  2.901034
# 23117    -44.898   -1.22610    1.30840    2.55300  2.340658  2.265129
# 14833    -44.898   -0.98810   -0.50876    4.02150  1.387450  1.484590
# 18904    -44.898    4.22610    4.00140    3.48130  1.754625  1.946445
# 28949    -44.898    9.78280   -0.43553    4.40870  1.126744  1.097373
# 23332    -41.709  -19.23500    5.15890    2.33760  2.219279  2.580393
# 3078     -41.709   -7.32060    6.32030    2.32930  1.824609  1.972158
# 33343    -41.709   -0.45843    0.29100    1.96440  1.707120  1.983095
# 44301    -41.709    1.82840    1.91560    1.89780  1.910933  1.949534
# 15284    -41.709    4.25360   -0.21293    4.19700  1.777705  1.899884
# 1349     -41.709    5.97280    3.60030    3.48630  1.424390  1.576365
# ...

# %%
subsetRiskFactorsEQ = pd.read_csv('Risk Factor Shocks_20140829.csv', usecols=[0, 141, 147, 153, 159, 165, 171, 177, 183,189], index_col=0)
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1070: DtypeWarning: Columns (0,165,171,141,177,147,183,153,189,159) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
subsetRiskFactorsEQ.to_csv("//NNResources.local/GROUPS/011081/Market Risk/Market Consistency/05 FLECS/subsetRiskFactorsCS_ZR2.csv")

# %%
subsetRiskFactorsEQ = pd.read_csv('Risk Factor Shocks_20140829.csv', usecols=[0, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672], index_col=0)
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1070: DtypeWarning: Columns (0,672,659,660,661,662,663,664,665,666,667,668,669,670,671) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
subsetRiskFactorsEQ.t
# Out:
#                      CS_GOV_SOV2_AA_15Y CS_GOV_SOV2_AA_9Y
# RiskFactorShock Type           ABSOLUTE          ABSOLUTE
# Base Level                            0                 0
# NaN                                 NaN               NaN
# Real World Shocks                   NaN               NaN
# 1                              -0.00115         -0.000633
# 2                              0.002649           0.00201
# 3                                0.0002          0.000336
# 4                             -0.001502         -0.000886
# 5                               0.01142          0.007119
# 6                             -0.002364         -0.001496
# 7                             -0.003243         -0.002105
# 8                              -0.00099         -0.000519
# 9                             -0.000104          0.000118
# 10                             0.000567          0.000597
# 11                            -0.001525         -0.000902
# ...
