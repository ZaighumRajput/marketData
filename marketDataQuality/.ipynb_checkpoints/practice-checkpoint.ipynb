# %%
cd inputFunctions
# Out:
# C:\Git\marketData\marketDataQuality\inputFunctions

# %%
import pandaLoad as pl

# %%
reload(pl)
networkMD = r"//srpzyfap0003.insim.biz/ESGShare/MD"
imp20140818 = pl.getDataSeries("20140818", "IDXIV", networkMD)
imp20140819 = pl.getDataSeries("20140819", "IDXIV", networkMD)

# %%
proper = imp20140819.pivot_table(rows = ['Date','Expiry', 'Moneyness'], values = 'Volatility', cols=['Index'])
proper2 = imp20140818.pivot_table(rows = ['Date','Expiry', 'Moneyness'], values = 'Volatility', cols=['Index'])

# %%
import pandas as pd
two = pd.concat([proper, proper2])

# %%
ppd._version__
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f2f2a32a2702> in <module>()
# ----> 1 two.xs(("19/08/2014", "30"))
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.pyc in xs(self, key, axis, level, copy, drop_level)
#    1293         if isinstance(index, MultiIndex):
#    1294             loc, new_index = self.index.get_loc_level(key,
# -> 1295                                                       drop_level=drop_level)
#    1296         else:
#    1297             loc = self.index.get_loc(key)
#
# C:\Anaconda\lib\site-packages\pandas\core\index.pyc in get_loc_level(self, key, level, drop_level)
#    3197                         return partial_selection(key)
#    3198                 else:
# -> 3199                     return partial_selection(key)
#    3200             else:
#    3201                 indexer = None
#
# ...

# %%
help(proper.xs)
# Out:
# Help on method xs in module pandas.core.generic:
#
# xs(self, key, axis=0, level=None, copy=True, drop_level=True) method of pandas.core.frame.DataFrame instance
#     Returns a cross-section (row(s) or column(s)) from the Series/DataFrame.
#     Defaults to cross-section on the rows (axis=0).
#
#     Parameters
#     ----------
#     key : object
#         Some label contained in the index, or partially in a MultiIndex
#     axis : int, default 0
#         Axis to retrieve cross-section on
#     level : object, defaults to first n levels (n=1 or len(key))
#         In case of a key partially contained in a MultiIndex, indicate
#         which levels are used. Levels can be referred by label or position.
#     copy : boolean, default True
#         Whether to make a copy of the data
#     drop_level : boolean, default True
#         If False, returns object with same levels as self.
#
#     Examples
#     --------
#     >>> df
#        A  B  C
#     a  4  5  2
#     b  4  0  9
# ...

# %%
proper.xs(('19/08/2014', 90), level=["Date","Expiry"]).plot(legend=False)

# %%
help(proper.xs(('19/08/2014', 90), level=["Date","Expiry"]).plot(legend=False))
# Out:
# Help on AxesSubplot in module matplotlib.axes object:
#
# class AxesSubplot(SubplotBase, Axes)
#  |  Method resolution order:
#  |      AxesSubplot
#  |      SubplotBase
#  |      Axes
#  |      matplotlib.artist.Artist
#  |      __builtin__.object
#  |
#  |  Methods inherited from SubplotBase:
#  |
#  |  __init__(self, fig, *args, **kwargs)
#  |      *fig* is a :class:`matplotlib.figure.Figure` instance.
#  |
#  |      *args* is the tuple (*numRows*, *numCols*, *plotNum*), where
#  |      the array of subplots in the figure has dimensions *numRows*,
#  |      *numCols*, and where *plotNum* is the number of the subplot
#  |      being created.  *plotNum* starts at 1 in the upper left
#  |      corner and increases to the right.
#  |
#  |
#  |      If *numRows* <= *numCols* <= *plotNum* < 10, *args* can be the
#  |      decimal integer *numRows* * 100 + *numCols* * 10 + *plotNum*.
#  |
#  |  __reduce__(self)
#  |
#  |  change_geometry(self, numrows, numcols, num)
# ...

# %%
reload(pl)
networkMD = r"//srpzyfap0003.insim.biz/ESGShare/MD"
imp20140818 = pl.getDataSeries("20140818", "IDXIV", networkMD)
imp20140819 = pl.getDataSeries("20140819", "IDXIV", networkMD)

# %%
imp20140818
# Out:
# Index                        BFIV_BCOPC3A2  BFIV_BCOPC3A8  BFIV_EUG4TR  \
# Date       Expiry Moneyness
# 18/08/2014 30     -0.40                NaN            NaN          NaN
#                   -0.30                NaN            NaN          NaN
#                   -0.25                NaN            NaN          NaN
#                   -0.20                NaN            NaN          NaN
#                   -0.15                NaN            NaN          NaN
#                   -0.10                NaN            NaN          NaN
#                   -0.05                NaN            NaN          NaN
#                    0.00                NaN            NaN          NaN
#                    0.05                NaN            NaN          NaN
#                    0.10                NaN            NaN          NaN
#                    0.15                NaN            NaN          NaN
#                    0.20                NaN            NaN          NaN
# ...

# %%
po.xs(("18/08/2014", 365), level = [0,1])["IRIV_EUR"].plot(legend=False)

# %%
po
# Out:
# Key                                IRIV_AUD  IRIV_BGN  IRIV_CAD  IRIV_CHF  \
# Date       Expiry Tenor Moneyness
# 18/08/2014 365    365   1             0.214       NaN    0.2591       NaN
#                   730   1             0.237       NaN    0.3010     5.201
#                   1095  1             0.229       NaN    0.3040     1.904
#                   1460  1               NaN       NaN       NaN     1.212
#                   1825  1             0.208       NaN    0.3126     0.904
#                   2190  1               NaN       NaN       NaN     0.720
#                   2555  1             0.201       NaN    0.2735     0.596
#                   2920  1               NaN       NaN       NaN     0.517
#                   3285  1               NaN       NaN       NaN     0.462
#                   3650  1             0.196       NaN    0.2390     0.418
#                   5475  1               NaN       NaN       NaN       NaN
# ...

# %%
a ={'f': {1,2}}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-f4e59431eb05> in <module>()
# ----> 1 a['f'][1]
#
# TypeError: 'set' object does not support indexing

# %%
pl.getDataSeries("20140818", "IDXIV", networkMD)
# Out:
# Index                        BFIV_BCOPC3A2  BFIV_BCOPC3A8  BFIV_EUG4TR  \
# Date       Expiry Moneyness
# 18/08/2014 30     -0.40                NaN            NaN          NaN
#                   -0.30                NaN            NaN          NaN
#                   -0.25                NaN            NaN          NaN
#                   -0.20                NaN            NaN          NaN
#                   -0.15                NaN            NaN          NaN
#                   -0.10                NaN            NaN          NaN
#                   -0.05                NaN            NaN          NaN
#                    0.00                NaN            NaN          NaN
#                    0.05                NaN            NaN          NaN
#                    0.10                NaN            NaN          NaN
#                    0.15                NaN            NaN          NaN
#                    0.20                NaN            NaN          NaN
# ...

# %%
reload(pl)
pl.getDataSeries("20140818", "IRC", networkMD)
# Out:
# Description          Australian Dollar swap zero
# Date       Maturity
# 18/08/2014 1                            0.025549
#            30                           0.026649
#            90                           0.026628
#            180                          0.026728
#            365                          0.026095
#            730                          0.026585
#            1095                         0.027952
#            1460                         0.030212
#            1825                         0.031798
#            2190                         0.033296
#            2555                         0.034822
#            2920                         0.035883
#            3285                         0.036964
#            3650                         0.038069
#            4015                         0.038890
#            4380                         0.039728
#            4745                         0.040290
#            5110                         0.040865
# ...
